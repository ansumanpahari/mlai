# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/coupons.csv')
data
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %% [markdown]
# ## Check NULL counts

# %%
null_counts = data.isnull().sum()
null_counts
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# ## Remove Unused
# `car` column has no significance. Can be removed.

# %%
data = data.drop('car',axis=1)
data
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %% [markdown]
# ## Pie Chart of several columns

# %%
data['destination'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['passanger'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['weather'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['time'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['coupon'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['expiration'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['age'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['maritalStatus'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['has_children'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['education'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['occupation'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['income'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Bar'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['CoffeeHouse'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['CarryAway'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['RestaurantLessThan20'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Restaurant20To50'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['toCoupon_GEQ5min'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['toCoupon_GEQ15min'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['toCoupon_GEQ25min'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['direction_same'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['direction_opp'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Y'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Remove toCoupon_GEQ5min
# This column has no impact as it has only one value. Hence can be removed from analysis. Further analysis few columns which will be used for further analysis.

# %%
data_coupon = data.query('coupon == "Bar" and Y == 1')
data_coupon = data_coupon[['passanger','occupation','gender','age','income','RestaurantLessThan20','Bar','Y']]
data_coupon['Bar'].value_counts()
# Out:
# Bar
# 1~3      257
# less1    253
# never    156
# 4~8      117
# gt8       36
# Name: count, dtype: int64

# %%
data_coupon['age'].value_counts()
# Out:
# age
# 21         211
# 26         193
# 31         125
# 50plus      84
# 41          77
# 36          63
# 46          38
# below21     36
# Name: count, dtype: int64

# %%
data_coupon['passanger'].value_counts()
# Out:
# passanger
# Alone        489
# Friend(s)    188
# Partner      107
# Kid(s)        43
# Name: count, dtype: int64

# %%
data_coupon['occupation'].value_counts()
# Out:
# occupation
# Student                                      120
# Unemployed                                    91
# Computer & Mathematical                       87
# Sales & Related                               80
# Management                                    65
# Office & Administrative Support               53
# Business & Financial                          41
# Education&Training&Library                    40
# Arts Design Entertainment Sports & Media      33
# Healthcare Support                            29
# Food Preparation & Serving Related            23
# Healthcare Practitioners & Technical          18
# Architecture & Engineering                    18
# Retired                                       18
# Life Physical Social Science                  15
# Protective Service                            13
# Construction & Extraction                     13
# Community & Social Services                   13
# Production Occupations                        12
# ...

# %%
data_coupon['income'].value_counts()
# Out:
# income
# $25000 - $37499     143
# $100000 or More     138
# $12500 - $24999     120
# $50000 - $62499     108
# $37500 - $49999      93
# Less than $12500     76
# $75000 - $87499      57
# $62500 - $74999      46
# $87500 - $99999      46
# Name: count, dtype: int64

# %%
data_coupon['RestaurantLessThan20'].value_counts()
# Out:
# RestaurantLessThan20
# 1~3      348
# 4~8      242
# less1    122
# gt8       85
# never     18
# Name: count, dtype: int64

# %%
grouped = data_coupon.groupby('RestaurantLessThan20')['Y'].sum()
grouped
# Out:
# RestaurantLessThan20
# 1~3      348
# 4~8      242
# gt8       85
# less1    122
# never     18
# Name: Y, dtype: int64

# %%
data['maritalStatus'].value_counts()
# Out:
# maritalStatus
# Married partner      5100
# Single               4752
# Unmarried partner    2186
# Divorced              516
# Widowed               130
# Name: count, dtype: int64
